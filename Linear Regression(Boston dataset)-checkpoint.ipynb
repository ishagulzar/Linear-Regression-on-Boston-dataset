# %% [markdown]
# ## Using the famous Boston Housing Dataset for Single Linear Regression

# %% [markdown]
# ### Importing relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# Setting random seed for reproducibility
# By setting the seed value to a specific number, such as 0 in this case, you ensure that the sequence of random numbers generated by NumPy will be the same every time you run the code.
# This can be helpful when you want to debug or test your code and need consistent results.

np.random.seed(0)

# %%
# Reading the dataset
df = pd.read_csv("boston.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# Name of the columns of our dataset 
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %% [raw]
# CRIM: Per capita crime rate by town.
#
# ZN: Proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS: Proportion of non-retail business acres per town.
#
# CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# NOX: Nitric oxides concentration (parts per 10 million).
#
# RM: Average number of rooms per dwelling.
#
# AGE: Proportion of owner-occupied units built prior to 1940.
#
# DIS: Weighted distances to five Boston employment centers.
#
# RAD: Index of accessibility to radial highways.
#
# TAX: Full-value property tax rate per $10,000.
#
# PTRATIO: Pupil-teacher ratio by town.
#
# B: 1000(Bk - 0.63)^2 where Bk is the proportion of Black individuals by town.
#
# LSTAT: Percentage of lower status of the population.
#
# The goal is to use these features to predict the median value of owner-occupied homes (MEDV) in the Boston area based on the available information.

# %%
# Splitting the dataset into features(X) and target variable(y)

X = df.iloc[:,:-1]
y = df.MEDV

# %%
# Splitting dataset into training and test sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Dimensions of training and test sets

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 13), (152, 13), (354,), (152,))

# %%
# Calculating the correlation coefficient between different features in the training and the target variable

X_train.CRIM.corr(y_train), X_train.ZN.corr(y_train), X_train.INDUS.corr(y_train), X_train.CHAS.corr(y_train), X_train.NOX.corr(y_train), X_train.RM.corr(y_train), X_train.AGE.corr(y_train), X_train.DIS.corr(y_train), X_train.RAD.corr(y_train), X_train.TAX.corr(y_train), X_train.PTRATIO.corr(y_train), X_train.B.corr(y_train), X_train.LSTAT.corr(y_train)
# Out:
# (-0.38818242157849747,
#  0.38611524489465904,
#  -0.5043608691245867,
#  0.16239486699835462,
#  -0.42669028353343524,
#  0.7089779707466815,
#  -0.39094173231882606,
#  0.24563407621506292,
#  -0.38953261912436266,
#  -0.4813185343326367,
#  -0.5647334555408697,
#  0.32443738875299755,
#  -0.743288689399348)

# %%
plt.scatter(X_train.RM, y_train)

# %% [raw]
# The feature that appears to have the highest correlation with the target variable is 'RM', with a value of 0.7089779707466815. Hence, for Single Linear Regression we choose the feature 'RM'.

# %%
# fitting the model
lm = LinearRegression()
model_slr = lm.fit(X_train[['RM']], y_train)

# %% [raw]
# The variable 'model_slr' will contain the trained linear regression model. It can be used to make predictions on new data or further analyze the model's coefficients, residuals, and other properties.

# %%
#---------------------------------------------#

# %% [raw]
# model_slr.intercept - This attribute represents the intercept or the y-intercept of the linear regression line. It indicates the predicted value of the dependent variable ('y') when all the independent variables ('X') are set to zero. In other words, it represents the point where the regression line intersects the y-axis.
#
# model_slr.coef - This attribute contains the coefficients or slopes of the independent variables ('X') in the linear regression equation. Each coefficient represents the change in the predicted value of the dependent variable ('y') for a one-unit change in the corresponding independent variable while holding all other variables constant. The coefficients indicate the strength and direction of the relationship between each independent variable and the dependent variable.

# %%
model_slr.intercept_ , model_slr.coef_
# Out:
# (-35.994348978183496, array([9.31132806]))

# %% [raw]
# With the above values, the Linear Regression model can be represented by the equation:
#
# y = -35.994348978183496 + 9.31132806*X
#
# This equation suggests that the intercept is -35.99, indicating the baseline value of the dependent variable when all independent variables are zero. The coefficient of 9.31 indicates the expected change in the dependent variable for a one-unit increase in the independent variable.

# %%
model_slr.predict(X_train[['RM']])
# Out:
# array([10.73920657, 24.8831139 , 22.9929143 , 23.08602758, 19.51047761,
#        21.19582799, 16.09322021, 15.86974833, 21.28894127, 20.7675069 ,
#        28.88698497, 33.02121463, 30.15332558, 20.64645963, 20.25538385,
#        25.63733147, 23.57952797, 18.82143933, 25.49766155, 13.39293507,
#        23.37467875, 22.20145142, 18.67245808, 21.95004556, 15.86043701,
#        14.19370928, 28.9987209 , 20.94442213, 22.67632915, 21.75450767,
#        18.65383543, 18.5141655 , 18.3465616 , 23.8868018 , 26.96885139,
#        25.78631272, 36.92266109, 23.93335844, 24.14751898, 32.22975174,
#        29.92054238, 17.12677762, 33.56127165, 21.83830962, 25.36730296,
#        17.62958934, 21.00960143, 35.19075407, 23.98922641, 14.80825693,
#        34.02683806, 31.73625135, 21.08409205, 20.48816705, 21.00960143,
#        24.40823617, 22.77875376, 18.72832605, 25.73975608, 25.74906741,
#        24.16614164, 17.89030652, 20.08777995, 23.41192407, 21.49379048,
# ...

# %%
# compute predictions using the model parameters
yhat_train = model_slr.intercept_ + model_slr.coef_ * X_train['RM']
yhat_train[0:5]
# Out:
# 141    10.739207
# 272    24.883114
# 135    22.992914
# 298    23.086028
# 122    19.510478
# Name: RM, dtype: float64

# %%
# calculate R Square = 1 - SSE/SST

# sum of squares of errors
SSE = sum((y_train - yhat_train)**2)

# %%
# total sum of squares or total variation in target
SST = sum((y_train - np.mean(y_train))**2)

# %%
# R Square
model_slr_r_square = 1 - SSE/SST
model_slr_r_square
# Out:
# 0.5026497630040827

# %%
# sum of squares of regression (variation explained by the model)
SSR = sum((yhat_train - np.mean(y_train))**2)

# %%
SSR/SST
# Out:
# 0.5026497630040825

# %%
# total variation = explained variation + unexplained variation
# SST = SSR + SSE
SST, SSR + SSE
# Out:
# (30006.637768361576, 30006.637768361565)

# %%
# get this using the model
model_slr.score(X_train[['RM']],y_train)
# Out:
# 0.5026497630040827

# %% [raw]
# correlation and R Square
# if r is the correlation between the feature and the label then R Square = r**2
#
# greater the correlation between feature and label, better is the fit of the linear model
#
# this property applies directly only in SLR.
#
# In MLR also, correlation improves R Square but this simple formula does not apply.

# %%
# correlation between feature and label (r)
r = X_train.RM.corr(y_train)
r
# Out:
# 0.7089779707466815

# %%
# this is almost as the model R Square. Shows that as correlation is higher model fit is better.
r**2
# Out:
# 0.5026497630040823

# %%
# plot the model
plt.scatter(X_train.RM,y_train)
plt.plot(X_train.RM,yhat_train,c='r')
plt.show()

# %%
# apply model to predict test data
yhat_test = model_slr.predict(X_test[['RM']])

# %%
plt.scatter(X_test.RM,y_test)
plt.plot(X_test.RM,yhat_test,c='r')
plt.show()

# %% [raw]
# *) MSE (Mean Squared Error) and MAPE (Mean Absolute Percentage Error) are two commonly used evaluation metrics in the field of machine learning and statistics. They are used to measure the performance and accuracy of regression models.

# %% [raw]
# Mean Squared Error (MSE):
# MSE measures the average squared difference between the predicted values and the actual values. It gives a higher weight to larger errors due to the squared term.
#
# MSE provides a measure of how well the model fits the data, with lower values indicating better performance.

# %%
# compute train and test MSE
mse_train = np.mean((y_train - yhat_train)**2)
mse_test = np.mean((y_test - yhat_test)**2)
mse_train,mse_test
# Out:
# (42.157650863122235, 47.03304747975518)

# %% [raw]
# Mean Absolute Percentage Error (MAPE):
# MAPE measures the average percentage difference between the predicted values and the actual values. It represents the average absolute percentage error as a percentage of the actual values.
#
# MAPE provides a relative measure of the prediction accuracy, allowing comparison between different models or datasets.

# %%
# compute train and test MAPE
mape_train = np.mean(abs(y_train - yhat_train)/y_train) * 100
mape_test = np.mean(abs(y_test - yhat_test)/y_test) * 100
mape_train,mape_test
# Out:
# (25.010088023296063, 27.538580447276402)

# %%
model_slr_performance = {'model':"model_slr",'R Sq':model_slr_r_square,'train_MSE':mse_train,'test_MSE':mse_test,'train_MAPE':mape_train,'test_MAPE':mape_test}

# %%
df_snapshot = pd.DataFrame(columns=['model','R Sq','train_MSE','test_MSE','train_MAPE','test_MAPE'])
df_snapshot
# Out:
# Empty DataFrame
# Columns: [model, R Sq, train_MSE, test_MSE, train_MAPE, test_MAPE]
# Index: []

# %%
df_snapshot = df_snapshot.append(model_slr_performance,ignore_index=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14692\1441778995.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_snapshot = df_snapshot.append(model_slr_performance,ignore_index=True)

# %%
df_snapshot
# Out:
#        model     R Sq  train_MSE   test_MSE  train_MAPE  test_MAPE
# 0  model_slr  0.50265  42.157651  47.033047   25.010088   27.53858
